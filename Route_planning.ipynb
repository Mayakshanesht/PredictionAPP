# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayakshanesht/PredictionAPP/blob/main/Route_planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive',force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
A=pd.read_excel("/content/drive/My Drive/Regression_model/Route_planning_1.xlsx")

# %%
A.head
# Out:
# <bound method NDFrame.head of      Time in sec  power 100 k lbs(HP)  ...  Elevation in m  Grade in %
# 0       0.000000           209.080878  ...        3.030220    0.508043
# 1       1.001163           116.612708  ...        3.132602   -0.264447
# 2       2.002326            93.348687  ...        3.079310   -0.458792
# 3       3.003488            88.339982  ...        2.986853   -0.500635
# 4       4.004651           105.967258  ...        2.885963   -0.353378
# ..           ...                  ...  ...             ...         ...
# 856   856.995349            39.445287  ...        7.221797   -0.909106
# 857   857.996512           101.048342  ...        7.038591   -0.394470
# 858   858.997674            18.847297  ...        6.959096   -1.081193
# 859   859.998837            83.174120  ...        6.741211   -0.543790
# 860   861.000000             0.000000  ...        6.631624    0.000000
#
# [861 rows x 5 columns]>

# %%
A.describe()
# Out:
#        Time in sec  power 100 k lbs(HP)  ...  Elevation in m  Grade in %
# count   861.000000           861.000000  ...      861.000000  861.000000
# mean    430.500000           150.563356  ...        3.130499    0.020756
# std     248.982765           164.114709  ...        3.257902    1.371427
# min       0.000000          -524.722268  ...       -1.883839   -5.629739
# 25%     215.250000            96.527827  ...        0.094084   -0.421591
# 50%     430.500000           148.268278  ...        3.122533   -0.012038
# 75%     645.750000           196.497550  ...        4.601131    0.409370
# max     861.000000          1143.909488  ...       11.868130    8.349340
#
# [8 rows x 5 columns]

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
corrMatrix = A.corr()
print (corrMatrix)
# Out:
#                      Time in sec  ...  Grade in %
# Time in sec             1.000000  ...    0.020850
# power 100 k lbs(HP)     0.022913  ...    0.987481
# power 80 K lbs(HP)      0.022759  ...    0.987400
# Elevation in m          0.358616  ...   -0.034008
# Grade in %              0.020850  ...    1.000000
#
# [5 rows x 5 columns]

# %%
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
Time=A.iloc[:,0] 
P1=A.iloc[:,1] 
P2=A.iloc[:,2]
Ele=A.iloc[:,3] 
Grade=A.iloc[:,4]

# %%
plt.plot(Time,P1)
plt.show()
plt.plot(Time,P2)
plt.show()
plt.plot(Time,Ele)
plt.show()
plt.plot(Time,Grade)

plt.show()
